# %%
import torch

# %%
mask = torch.zeros(5, dtype=torch.bool)

# %%
mask
# Out:
# tensor([False, False, False, False, False])

# %%
ids = torch.tensor([1, 4])

# %%
ids
# Out:
# tensor([1, 4])

# %%
mask.scatter_(0, ids, True)
# Out:
# tensor([False,  True, False, False,  True])

# %%
depths = torch.randn(1, 1080, 1920, 1)

# %%
depths.shape
# Out:
# torch.Size([1, 1080, 1920, 1])

# %%
out = depths.permute(0, 3, 1, 2)

# %%
out.shape
# Out:
# torch.Size([1, 1, 1080, 1920])
